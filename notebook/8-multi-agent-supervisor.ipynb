# %%
import setup
setup.init()

# %%
from ai.supervisors import get_supervisor

# %%
from langgraph.checkpoint.memory import InMemorySaver

checkpointer = InMemorySaver()

# %%
supervisor = get_supervisor(model= "gemini-1.5-flash", checkpointer = checkpointer)

# %%
import uuid
config = {"configurable" : {"user_id" : "2" , "thread_id": uuid.uuid4()}}

response = supervisor.invoke(
    {
        "messages": 
        [
            {"role": "user" , "content": "tell about me the mission impossible movie"}
        ]
    },
    config
)
# Out:
# Searching for user: 2

# %%
response['messages'][-1].content
# Out:
# 'Here is the information about the movie "Mission: Impossible - The Final Reckoning":\n- Title: Mission: Impossible - The Final Reckoning\n- Release Date: May 17, 2025\n- Overview: Ethan Hunt and his team search for the AI known as the Entity to prevent it from changing the world. They are pursued by governments and a mysterious ghost from Hunt\'s past.\n- Average Rating: 7.192\n- Total Votes: 2492\n\nIf you have any more questions or need further details, feel free to ask!'

# %%
from ai.tools import documents_tools

list_tool = documents_tools[1]  # list_documents
try:
    result = list_tool.invoke({"limit": 5}, config={"configurable": {"user_id": "2"}})
    print(f"List tool result: {result}")
except Exception as e:
    print(f"List tool error: {e}")
# Out:
# List tool error: You cannot use AsyncToSync in the same thread as an async event loop - just await the async function directly.

# %%
# Debug: Check what's in the database
import setup
setup.init()

from documents.models import Document

# Check total documents
total_docs = Document.objects.all()
print(f"Total documents in database: {total_docs.count()}")

# Check what user_ids exist
if total_docs.exists():
    for doc in total_docs[:5]:
        print(f"Doc: '{doc.title}', owner_id: {doc.owner_id} (type: {type(doc.owner_id)})")

# Check documents for user "2" specifically
user_docs = Document.objects.filter(owner_id="2")
print(f"Documents for owner_id='2': {user_docs.count()}")

# Check if owner_id is stored as integer
user_docs_int = Document.objects.filter(owner_id=2)
print(f"Documents for owner_id=2 (int): {user_docs_int.count()}")
# Out:
# Total documents in database: 6
# Doc: 'Title', owner_id: 1 (type: <class 'int'>)
# Doc: 'Title-1', owner_id: 1 (type: <class 'int'>)
# Doc: 'Title-2', owner_id: 1 (type: <class 'int'>)
# Doc: 'Title-1', owner_id: 1 (type: <class 'int'>)
# Doc: 'Title', owner_id: 2 (type: <class 'int'>)
# Documents for owner_id='2': 2
# Documents for owner_id=2 (int): 2
